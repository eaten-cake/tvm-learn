# %%
import os

import numpy as np
import tvm
from tvm import te, auto_scheduler

# %%
@auto_scheduler.register_workload  # Note the auto_scheduler decorator
def matmul_add(N, L, M, dtype):
    A = te.placeholder((N, L), name="A", dtype=dtype)
    B = te.placeholder((L, M), name="B", dtype=dtype)
    C = te.placeholder((N, M), name="C", dtype=dtype)

    k = te.reduce_axis((0, L), name="k")
    matmul = te.compute(
        (N, M),
        lambda i, j: te.sum(A[i, k] * B[k, j], axis=k),
        name="matmul",
        attrs={"layout_free_placeholders": [B]},  # enable automatic layout transform for tensor B
    )
    out = te.compute((N, M), lambda i, j: matmul[i, j] + C[i, j], name="out")

    return [A, B, C, out]

# %%
A, B, C, out = matmul_add(1024, 1024, 1024, "float32")

# %%
func = te.create_prim_func([A, B, C, out])

# %%
print(dir(func))
print(func.params)
# Out:
# ['__annotations__', '__class__', '__del__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_handle_by_constructor__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_checked_type_', '_move', '_relax_script', 'attrs', 'attrs', 'body', 'buffer_map', 'checked_type', 'handle', 'legacy_repr', 'params', 'ret_type', 'same_as', 'script', 'show', 'span', 'specialize', 'struct_info', 'with_attr', 'with_attrs', 'with_body', 'without_attr']
# [var_A, var_B, var_C, var_out]

# %%
print(task.workload_key)
for ele in task.workload_key:
    print(ele)
# Out:
# ["matmul_add", 1024, 1024, 1024, "float32"]
# [
# "
# m
# a
# t
# m
# u
# l
# _
# a
# d
# d
# "
# ,
#
# 1
# 0
# 2
# 4
# ,
#
# 1
# 0
# 2
# 4
# ,
#
# 1
# 0
# 2
# 4
# ,
#
# "
# f
# l
# o
# a
# t
# 3
# 2
# "
# ]

# %%
target = tvm.target.Target("llvm")
N = L = M = 1024
task = tvm.auto_scheduler.SearchTask(func=matmul_add, args=(N, L, M, "float32"), target=target)

# 检查计算图
print("Computational DAG:")
print(task.compute_dag)
# Out:
# Computational DAG:
# A = PLACEHOLDER [1024, 1024]
# B = PLACEHOLDER [1024, 1024]
# matmul(i, j) += (A[i, k]*B[k, j])
# C = PLACEHOLDER [1024, 1024]
# out(i, j) = (matmul[i, j] + C[i, j])

# %%
log_file = "matmul.json"
tune_option = auto_scheduler.TuningOptions(
    num_measure_trials=10,
    measure_callbacks=[auto_scheduler.RecordToFile(log_file)],
    verbose=2,
)

# %%
# 运行 auto-tuning（搜索）
task.tune(tune_option)
# 应用最佳 schedule
sch, args = task.apply_best(log_file)
# Out:
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 2014	fail_ct: 3	Time elapsed: 1.58
# GA Iter: 0	Max score: 0.9989	Min score: 0.9405	#Pop: 128	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9999	Min score: 0.9883	#Pop: 128	#M+: 1371	#M-: 72
# EvolutionarySearch		#s: 128	Time elapsed: 6.93
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 10 programs to measure:
# ..........**********
# ==================================================
# No: 1	GFLOPS: 60.02 / 60.02	results: MeasureResult(cost:[0.0358], error_no:0, all_cost:0.98, Tstamp:1732991436.56)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,64)
#   for j.1 (0,4)
#     for k.0 (0,1024)
#       for i.2 (0,16)
#         for j.2 (0,64)
#           for i.3 (0,2)
#             vectorize j.3 (0,2)
#               matmul = ...
#   for i.1 (0,32)
#     for j.1 (0,512)
#       out = ...
#
# ==================================================
# No: 2	GFLOPS: 43.79 / 60.02	results: MeasureResult(cost:[0.0491], error_no:0, all_cost:1.00, Tstamp:1732991436.95)
# ==================================================
# Placeholder: A, B, C
# parallel i.0 (0,256)
#   for j.0 (0,16)
#     matmul auto_unroll: 16
#     for i.1 (0,2)
#       for j.1 (0,4)
#         for k.0 (0,1024)
#           for j.2 (0,16)
#             for i.3 (0,2)
#               matmul = ...
#     for i.1 (0,4)
#       for j.1 (0,64)
#         out = ...
#
# ==================================================
# No: 3	GFLOPS: 74.13 / 74.13	results: MeasureResult(cost:[0.0290], error_no:0, all_cost:0.99, Tstamp:1732991437.37)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,512)
#   for i.1 (0,16)
#     for j.1 (0,16)
#       matmul auto_unroll: 512
#       for k.0 (0,32)
#         for i.2 (0,4)
#           for k.1 (0,32)
#             vectorize j.3 (0,2)
#               matmul = ...
#       for i.2 (0,4)
#         vectorize j.2 (0,2)
#           out = ...
#
# ==================================================
# No: 4	GFLOPS: 112.84 / 112.84	results: MeasureResult(cost:[0.0190], error_no:0, all_cost:0.94, Tstamp:1732991437.73)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,32)
#   matmul auto_unroll: 16
#   for i.1 (0,8)
#     for j.1 (0,4)
#       for k.0 (0,1024)
#         for i.3 (0,64)
#           for j.3 (0,16)
#             matmul = ...
#   for i.1 (0,512)
#     for j.1 (0,64)
#       out = ...
#
# ==================================================
# No: 5	GFLOPS: 32.04 / 112.84	results: MeasureResult(cost:[0.0671], error_no:0, all_cost:0.92, Tstamp:1732991438.16)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@ (0,65536)
#   for k.0 (0,16)
#     for j.2 (0,4)
#       for k.1 (0,64)
#         vectorize j.3 (0,4)
#           matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 6	GFLOPS: 125.73 / 125.73	results: MeasureResult(cost:[0.0171], error_no:0, all_cost:1.06, Tstamp:1732991438.72)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@ (0,16)
#   matmul auto_unroll: 16
#   for i.1 (0,2)
#     for j.1 (0,32)
#       for k.0 (0,256)
#         for i.2 (0,8)
#           for j.2 (0,8)
#             for k.1 (0,4)
#               for i.3 (0,4)
#                 vectorize j.3 (0,4)
#                   matmul = ...
#   for i.1 (0,64)
#     for j.1 (0,1024)
#       out = ...
#
# ==================================================
# No: 7	GFLOPS: 36.63 / 125.73	results: MeasureResult(cost:[0.0586], error_no:0, all_cost:0.95, Tstamp:1732991439.17)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@ (0,256)
#   for j.1 (0,8)
#     for k.0 (0,32)
#       for i.2 (0,2)
#         for j.2 (0,16)
#           for k.1 (0,32)
#             for i.3 (0,8)
#               vectorize j.3 (0,2)
#                 matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# ==================================================
# No: 8	GFLOPS: 216.11 / 216.11	results: MeasureResult(cost:[0.0099], error_no:0, all_cost:0.99, Tstamp:1732991439.68)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@j.1@ (0,4096)
#   matmul auto_unroll: 16
#   for k.0 (0,64)
#     for i.2 (0,8)
#       for j.2 (0,2)
#         for k.1 (0,16)
#           vectorize j.3 (0,16)
#             matmul = ...
#   for i.2 (0,8)
#     for j.2 (0,32)
#       out = ...
#
# ==================================================
# No: 9	GFLOPS: 54.73 / 216.11	results: MeasureResult(cost:[0.0393], error_no:0, all_cost:0.77, Tstamp:1732991440.03)
# ==================================================
# Placeholder: A, B, C
# parallel i.0@j.0@i.1@ (0,256)
#   for j.1 (0,4)
#     matmul auto_unroll: 64
#     for k.0 (0,16)
#       for i.2 (0,64)
#         for j.2 (0,2)
#           for k.1 (0,64)
#             for i.3 (0,8)
#               matmul = ...
#     for i.2 (0,512)
#       vectorize j.2 (0,2)
#         out = ...
#
# ==================================================
# No: 10	GFLOPS: 33.35 / 216.11	results: MeasureResult(cost:[0.0644], error_no:0, all_cost:6.05, Tstamp:1732991440.53)
# ==================================================
# Placeholder: A, B, C
# matmul auto_unroll: 512
# parallel i.0@j.0@i.1@j.1@ (0,256)
#   for k.0 (0,512)
#     for i.2 (0,2)
#       for j.2 (0,4)
#         for k.1 (0,2)
#           for i.3 (0,64)
#             vectorize j.3 (0,8)
#               matmul = ...
# parallel i (0,1024)
#   for j (0,1024)
#     out = ...
#
# Time elapsed for measurement: 13.26 s
# ----------------------------------------------------------------------
# ------------------------------  [ Done ]
# ----------------------------------------------------------------------

# %%
task.compute_dag
# Out:
# A = PLACEHOLDER [1024, 1024]
# B = PLACEHOLDER [1024, 1024]
# matmul(i, j) += (A[i, k]*B[k, j])
# C = PLACEHOLDER [1024, 1024]
# out(i, j) = (matmul[i, j] + C[i, j])

# %%
tvm.lower(sch, args).show()
# Out:
# <div class="highlight" style="background: "><pre style="line-height: 125%;"><span></span><span style="color: #007979; font-style: italic"># from tvm.script import ir as I</span>
# <span style="color: #007979; font-style: italic"># from tvm.script import tir as T</span>
#
# <span style="color: #AA22FF">@I</span><span style="color: #AA22FF; font-weight: bold">.</span>ir_module
# <span style="color: #008000; font-weight: bold">class</span> <span style="color: #0000FF; font-weight: bold">Module</span>:
#     <span style="color: #AA22FF">@T</span><span style="color: #AA22FF; font-weight: bold">.</span>prim_func
#     <span style="color: #008000; font-weight: bold">def</span> <span style="color: #0000FF">main</span>(A: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>), B: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>), C: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>), out: T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((<span style="color: #008000">1024</span>, <span style="color: #008000">1024</span>), <span style="color: #BA2121">&quot;float32&quot;</span>)):
#         T<span style="color: #AA22FF; font-weight: bold">.</span>func_attr({<span style="color: #BA2121">&quot;from_legacy_te_schedule&quot;</span>: T<span style="color: #AA22FF; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>), <span style="color: #BA2121">&quot;tir.noalias&quot;</span>: T<span style="color: #AA22FF; font-weight: bold">.</span>bool(<span style="color: #008000; font-weight: bold">True</span>)})
#         auto_scheduler_layout_transform <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>allocate([<span style="color: #008000">1048576</span>], <span style="color: #BA2121">&quot;float32&quot;</span>, <span style="color: #BA2121">&quot;global&quot;</span>)
#         auto_scheduler_layout_transform_1 <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((<span style="color: #008000">1048576</span>,), data<span style="color: #AA22FF; font-weight: bold">=</span>auto_scheduler_layout_transform)
#         <span style="color: #008000; font-weight: bold">for</span> ax0_ax1_fused_ax2_fused <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>parallel(<span style="color: #008000">8</span>):
#             <span style="color: #008000; font-weight: bold">for</span> ax4, ax5, ax6, ax7 <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(<span style="color: #008000">16</span>, <span style="color: #008000">8</span>, <span style="color: #008000">64</span>, <span style="color: #008000">16</span>):
#                 B_1 <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((<span style="color: #008000">1048576</span>,), data<span style="color: #AA22FF; font-weight: bold">=</span>B<span style="color: #AA22FF; font-weight: bold">.</span>data)
#                 auto_scheduler_layout_transform_1[ax0_ax1_fused_ax2_fused <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">131072</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax4 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">8192</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax5 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">1024</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax6 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">16</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax7] <span style="color: #AA22FF; font-weight: bold">=</span> B_1[ax4 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">65536</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax6 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">1024</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax0_ax1_fused_ax2_fused <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">128</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax5 <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">16</span> <span style="color: #AA22FF; font-weight: bold">+</span> ax7]
#         <span style="color: #008000; font-weight: bold">for</span> i_outer_outer_j_outer_outer_fused_i_outer_inner_fused_j_outer_inner_fused <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>parallel(<span style="color: #008000">512</span>):
#             matmul <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>allocate([<span style="color: #008000">2048</span>], <span style="color: #BA2121">&quot;float32&quot;</span>, <span style="color: #BA2121">&quot;global&quot;</span>)
#             matmul_1 <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>Buffer((<span style="color: #008000">2048</span>,), data<span style="color: #AA22FF; font-weight: bold">=</span>matmul)
#             <span style="color: #008000; font-weight: bold">for</span> i_outer_inner_init, j_outer_inner_init <span style="color: #008000; font-weight: bold">in</span> T<span style="color: #AA22FF; font-weight: bold">.</span>grid(<span style="color: #008000">2</span>, <span style="color: #008000">8</span>):
#                 cse_var_1: T<span style="color: #AA22FF; font-weight: bold">.</span>int32 <span style="color: #AA22FF; font-weight: bold">=</span> i_outer_inner_init <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">1024</span> <span style="color: #AA22FF; font-weight: bold">+</span> j_outer_inner_init <span style="color: #AA22FF; font-weight: bold">*</span> <span style="color: #008000">16</span>
#                 matmul_1[cse_var_1] <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">0.0</span>)
#                 matmul_1[cse_var_1 <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">1</span>] <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">0.0</span>)
#                 matmul_1[cse_var_1 <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">2</span>] <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">0.0</span>)
#                 matmul_1[cse_var_1 <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">3</span>] <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">0.0</span>)
#                 matmul_1[cse_var_1 <span style="color: #AA22FF; font-weight: bold">+</span> <span style="color: #008000">4</span>] <span style="color: #AA22FF; font-weight: bold">=</span> T<span style="color: #AA22FF; font-weight: bold">.</span>float32(<span style="color: #008000">0.0</span>)

# %%
func = tvm.build(sch, args, target)
a_np = np.random.uniform(size=(N, L)).astype(np.float32)
b_np = np.random.uniform(size=(L, M)).astype(np.float32)
c_np = np.random.uniform(size=(N, M)).astype(np.float32)
out_np = a_np.dot(b_np) + c_np

dev = tvm.cpu()
a_tvm = tvm.nd.array(a_np, device=dev)
b_tvm = tvm.nd.array(b_np, device=dev)
c_tvm = tvm.nd.array(c_np, device=dev)
out_tvm = tvm.nd.empty(out_np.shape, device=dev)
func(a_tvm, b_tvm, c_tvm, out_tvm)

# Check results
np.testing.assert_allclose(out_np, out_tvm.numpy(), rtol=1e-5)

# Evaluate execution time.
evaluator = func.time_evaluator(func.entry_name, dev, min_repeat_ms=500)
print(
    "Execution time of this operator: %.3f ms"
    % (np.median(evaluator(a_tvm, b_tvm, c_tvm, out_tvm).results) * 1000)
)
# Out:
# Execution time of this operator: 9.953 ms
