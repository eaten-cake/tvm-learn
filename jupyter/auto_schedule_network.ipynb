# %%
import numpy as np

import tvm
from tvm import relay, auto_scheduler
from tvm.relay import data_dep_optimization as ddo
import tvm.relay.testing
from tvm.contrib import graph_executor

# %%
def get_network(name, batch_size, layout="NHWC", dtype="float32", use_sparse=False):
    """Get the symbol definition and random weight of a network"""

    # auto-scheduler 更适合 NHWC 布局
    if layout == "NHWC":
        image_shape = (224, 224, 3)
    elif layout == "NCHW":
        image_shape = (3, 224, 224)
    else:
        raise ValueError("Invalid layout: " + layout)

    input_shape = (batch_size,) + image_shape
    output_shape = (batch_size, 1000)

    if name.startswith("resnet-"):
        n_layer = int(name.split("-")[1])
        mod, params = relay.testing.resnet.get_workload(
            num_layers=n_layer,
            batch_size=batch_size,
            layout=layout,
            dtype=dtype,
            image_shape=image_shape,
        )
    elif name.startswith("resnet3d-"):
        n_layer = int(name.split("-")[1])
        mod, params = relay.testing.resnet.get_workload(
            num_layers=n_layer,
            batch_size=batch_size,
            layout=layout,
            dtype=dtype,
            image_shape=image_shape,
        )
    elif name == "mobilenet":
        mod, params = relay.testing.mobilenet.get_workload(
            batch_size=batch_size, layout=layout, dtype=dtype, image_shape=image_shape
        )
    elif name == "squeezenet_v1.1":
        assert layout == "NCHW", "squeezenet_v1.1 only supports NCHW layout"
        mod, params = relay.testing.squeezenet.get_workload(
            version="1.1",
            batch_size=batch_size,
            dtype=dtype,
            image_shape=image_shape,
        )
    elif name == "inception_v3":
        input_shape = (batch_size, 3, 299, 299) if layout == "NCHW" else (batch_size, 299, 299, 3)
        mod, params = relay.testing.inception_v3.get_workload(batch_size=batch_size, dtype=dtype)
    elif name == "mxnet":
        # MXNet 模型的示例
        from mxnet.gluon.model_zoo.vision import get_model
        assert layout == "NCHW"

        block = get_model("resnet50_v1", pretrained=True)
        mod, params = relay.frontend.from_mxnet(block, shape={"data": input_shape}, dtype=dtype)
        net = mod["main"]
        net = relay.Function(
            net.params, relay.nn.softmax(net.body), None, net.type_params, net.attrs
        )
        mod = tvm.IRModule.from_expr(net)
    elif name == "mlp":
        mod, params = relay.testing.mlp.get_workload(
            batch_size=batch_size, dtype=dtype, image_shape=image_shape, num_classes=1000
        )
    else:
        raise ValueError("Network not found.")

    if use_sparse:
        from tvm.topi.sparse.utils import convert_model_dense_to_sparse

        mod, params = convert_model_dense_to_sparse(mod, params, bs_r=4, random_params=True)

    return mod, params, input_shape, output_shape

# 定义神经网络和编译 target。
# 若 target 机器支持 avx512 指令，
# 使用 "llvm -mcpu=skylake-avx512" 替换 "llvm -mcpu=core-avx2"
network = "resnet-50"
use_sparse = False
batch_size = 1
layout = "NHWC"
target = tvm.target.Target("llvm -mcpu=core-avx2 --num-cores=1")
dtype = "float32"
log_file = "%s-%s-B%d-%s.json" % (network, layout, batch_size, target.kind.name)

# %%
# 从网络中提取任务
print("Get model...")
mod, params, input_shape, output_shape = get_network(
    network,
    batch_size,
    layout,
    dtype=dtype,
    use_sparse=use_sparse,
)
print("Extract tasks...")
tasks, task_weights = auto_scheduler.extract_tasks(mod["main"], params, target)

# for idx, task in enumerate(tasks):
#     print("========== Task %d  (workload key: %s) ==========" % (idx, task.workload_key))
#     print(task.compute_dag)
# Out:
# Get model...
# Extract tasks...

# %%
def run_tuning():
    print("Begin tuning...")
    trials = 50
    tuner = auto_scheduler.TaskScheduler(tasks, task_weights)
    tune_option = auto_scheduler.TuningOptions(
        num_measure_trials=trials,  # 将此更改为 20000 以达到最佳性能
        runner=auto_scheduler.LocalRunner(repeat=10, enable_cpu_cache_flush=True),
        measure_callbacks=[auto_scheduler.RecordToFile(log_file)],
    )

    if use_sparse:
        from tvm.topi.sparse.utils import sparse_sketch_rules

        search_policy = [
            auto_scheduler.SketchPolicy(
                task,
                program_cost_model=auto_scheduler.XGBModel(),
                init_search_callbacks=sparse_sketch_rules(),
            )
            for task in tasks
        ]

        tuner.tune(tune_option, search_policy=search_policy)
    else:
        tuner.tune(tune_option)

# 不在网页服务器中运行调优，因为它需要的时间太长。
# 取消注释运行以下行。
run_tuning()
# Out:
# Begin tuning...
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |            - |              - |      0 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |            - |              - |      0 |
# |    2 |                                        vm_mod_fused_nn_conv2d |            - |              - |      0 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |            - |              - |      0 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      0 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   13 |                                       vm_mod_fused_nn_softmax |            - |              - |      0 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 0	Used time : 0 s	Next ID: 0
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 2005	fail_ct: 1	Time elapsed: 2.28
# GA Iter: 0	Max score: 0.9999	Min score: 0.9999	#Pop: 2	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9999	Min score: 0.9999	#Pop: 2	#M+: 1387	#M-: 78
# EvolutionarySearch		#s: 2	Time elapsed: 10.19
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .*
# Time elapsed for measurement: 2.48 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.49 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |            - |              - |      0 |
# |    2 |                                        vm_mod_fused_nn_conv2d |            - |              - |      0 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |            - |              - |      0 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      0 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   13 |                                       vm_mod_fused_nn_softmax |            - |              - |      0 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 1	Used time : 15 s	Next ID: 1
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 2026	fail_ct: 0	Time elapsed: 2.47
# GA Iter: 0	Max score: 0.9995	Min score: 0.9993	#Pop: 2	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 1.0000	Min score: 1.0000	#Pop: 2	#M+: 1372	#M-: 74
# EvolutionarySearch		#s: 2	Time elapsed: 10.74
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .*
# Time elapsed for measurement: 6.09 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.04 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        4.220 |          24.54 |      1 |
# |    2 |                                        vm_mod_fused_nn_conv2d |            - |              - |      0 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |            - |              - |      0 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      0 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   13 |                                       vm_mod_fused_nn_softmax |            - |              - |      0 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 2	Used time : 35 s	Next ID: 2
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 2030	fail_ct: 0	Time elapsed: 2.30
# GA Iter: 0	Max score: 0.9983	Min score: 0.9983	#Pop: 2	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9999	Min score: 0.9999	#Pop: 2	#M+: 1378	#M-: 80
# EvolutionarySearch		#s: 2	Time elapsed: 10.01
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .*
# Time elapsed for measurement: 3.53 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.04 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        4.220 |          24.54 |      1 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        2.429 |          42.30 |      1 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |            - |              - |      0 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      0 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   13 |                                       vm_mod_fused_nn_softmax |            - |              - |      0 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 3	Used time : 51 s	Next ID: 3
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 2014	fail_ct: 0	Time elapsed: 2.43
# GA Iter: 0	Max score: 0.9997	Min score: 0.9996	#Pop: 2	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9999	Min score: 0.9998	#Pop: 2	#M+: 1389	#M-: 77
# EvolutionarySearch		#s: 2	Time elapsed: 10.78
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .*
# Time elapsed for measurement: 3.14 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.06 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        4.220 |          24.54 |      1 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        2.429 |          42.30 |      1 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.402 |          64.97 |      1 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      0 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   13 |                                       vm_mod_fused_nn_softmax |            - |              - |      0 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 4	Used time : 67 s	Next ID: 4
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 1642	fail_ct: 237	Time elapsed: 1.07
# GA Iter: 0	Max score: 0.9995	Min score: 0.9987	#Pop: 2	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 1.0000	Min score: 0.9996	#Pop: 2	#M+: 1385	#M-: 72
# EvolutionarySearch		#s: 2	Time elapsed: 4.62
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .E
# Time elapsed for measurement: 1.35 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.08 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        4.220 |          24.54 |      1 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        2.429 |          42.30 |      1 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.402 |          64.97 |      1 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      1 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |            - |              - |      0 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   13 |                                       vm_mod_fused_nn_softmax |            - |              - |      0 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 5	Used time : 74 s	Next ID: 5
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 2031	fail_ct: 0	Time elapsed: 2.51
# GA Iter: 0	Max score: 0.9998	Min score: 0.9993	#Pop: 2	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9998	Min score: 0.9998	#Pop: 2	#M+: 1387	#M-: 69
# EvolutionarySearch		#s: 2	Time elapsed: 10.82
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .*
# Time elapsed for measurement: 2.42 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.06 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        4.220 |          24.54 |      1 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        2.429 |          42.30 |      1 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.402 |          64.97 |      1 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      1 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |        1.002 |         104.96 |      1 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |            - |              - |      0 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   13 |                                       vm_mod_fused_nn_softmax |            - |              - |      0 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 6	Used time : 90 s	Next ID: 6
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 1946	fail_ct: 23	Time elapsed: 1.82
# GA Iter: 0	Max score: 0.9995	Min score: 0.9991	#Pop: 2	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9999	Min score: 0.9998	#Pop: 2	#M+: 1387	#M-: 68
# EvolutionarySearch		#s: 2	Time elapsed: 8.09
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .*
# Time elapsed for measurement: 2.40 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.04 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        4.220 |          24.54 |      1 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        2.429 |          42.30 |      1 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.402 |          64.97 |      1 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      1 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |        1.002 |         104.96 |      1 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |        5.027 |          40.88 |      1 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |            - |              - |      0 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   13 |                                       vm_mod_fused_nn_softmax |            - |              - |      0 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 7	Used time : 103 s	Next ID: 7
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 1
# Sample Iter: 5	#Pop: 8	#Target: 50	fail_ct: 7654	Time elapsed: 3.55
# #Target has been reduced to 25 due to too many failures or duplications
# Sample Iter: 10	#Pop: 8	#Target: 25	fail_ct: 15299	Time elapsed: 7.07
# #Target has been reduced to 12 due to too many failures or duplications
# Sample Iter: 15	#Pop: 8	#Target: 12	fail_ct: 22951	Time elapsed: 10.60
# #Target has been reduced to 6 due to too many failures or duplications
# Sample Initial Population	#s: 8	fail_ct: 24455	Time elapsed: 11.30
# GA Iter: 0	Max score: 0.9920	Min score: 0.9524	#Pop: 2	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9995	Min score: 0.9994	#Pop: 2	#M+: 350	#M-: 6662
# EvolutionarySearch		#s: 2	Time elapsed: 2.77
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .*
# Time elapsed for measurement: 2.25 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.05 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        4.220 |          24.54 |      1 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        2.429 |          42.30 |      1 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.402 |          64.97 |      1 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      1 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |        1.002 |         104.96 |      1 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |        5.027 |          40.88 |      1 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |        0.007 |          -0.00 |      1 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |            - |              - |      0 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   13 |                                       vm_mod_fused_nn_softmax |            - |              - |      0 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 8	Used time : 119 s	Next ID: 8
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 1921	fail_ct: 29	Time elapsed: 2.03
# GA Iter: 0	Max score: 0.9994	Min score: 0.9990	#Pop: 2	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 1.0000	Min score: 1.0000	#Pop: 2	#M+: 1382	#M-: 74
# EvolutionarySearch		#s: 2	Time elapsed: 9.11
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .*
# Time elapsed for measurement: 2.71 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.07 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        4.220 |          24.54 |      1 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        2.429 |          42.30 |      1 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.402 |          64.97 |      1 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      1 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |        1.002 |         104.96 |      1 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |        5.027 |          40.88 |      1 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |        0.007 |          -0.00 |      1 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |        0.814 |          63.15 |      1 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |            - |              - |      0 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |            - |              - |      0 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      0 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |            - |              - |      0 |
# |   13 |                                       vm_mod_fused_nn_softmax |            - |              - |      0 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |            - |              - |      0 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |            - |              - |      0 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |            - |              - |      0 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# ...
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 16	Used time : 248 s	Next ID: 16
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 1978	fail_ct: 4	Time elapsed: 2.21
# GA Iter: 0	Max score: 0.9994	Min score: 0.9994	#Pop: 2	#M+: 0	#M-: 0
# GA Iter: 4	Max score: 0.9999	Min score: 0.9995	#Pop: 2	#M+: 1382	#M-: 77
# EvolutionarySearch		#s: 2	Time elapsed: 9.78
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .*
# Time elapsed for measurement: 2.87 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.08 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        4.220 |          24.54 |      1 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        2.429 |          42.30 |      1 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.402 |          64.97 |      1 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      1 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |        1.002 |         104.96 |      1 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |        5.027 |          40.88 |      1 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |        0.007 |          -0.00 |      1 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |        0.814 |          63.15 |      1 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |        1.263 |          81.44 |      1 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |        1.432 |          36.02 |      1 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      1 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |        0.452 |         230.07 |      1 |
# |   13 |                                       vm_mod_fused_nn_softmax |        0.206 |           0.02 |      1 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |        9.900 |          10.40 |      1 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |        2.081 |          49.42 |      1 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |       29.808 |           3.45 |      1 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |            - |              - |      0 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 17	Used time : 263 s	Next ID: 17
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 1
# Sample Initial Population	#s: 95	fail_ct: 1643	Time elapsed: 1.85
# GA Iter: 0	Max score: 0.9965	Min score: 0.9893	#Pop: 2	#M+: 0	#M-: 0
# [00:59:15] /home/yrx/develop/tvm/src/auto_scheduler/compute_dag.cc:1387: Warning: InferBound fails on the state:
# Placeholder: p0, p1
# parallel ax0@ax1@ (0,56)
#   pool_max auto_unroll: 16
#   for ax0 (None)
#     for ax1 (None)
#       for ax2 (None)
#         for ax3 (None)
#           for rv0 (None)
#             for rv1 (None)
#               pool_max = ...
#   for ax2 (0,56)
#     for ax0 (None)
#       for ax1 (None)
#         for ax2 (None)
#           for ax3 (None)
#             pad_temp = ...
#     for ax3 (0,64)
#       T_relu = ...
#
# with: [00:59:15] /home/yrx/develop/tvm/src/te/schedule/bound.cc:175: InternalError: Check failed: (found_attach || stage_attach.size() == 0) is false: Invalid Schedule, cannot find the producer compute(pad_temp, body=[T.if_then_else(ax1 >= 1 and ax1 < 113 and ax2 >= 1 and ax2 < 113, p0[ax0, ax1 - 1, ax2 - 1, ax3], T.float32(-340282346638528859811704183484516925440.0))], axis=[T.iter_var(ax0, T.Range(0, 1), "DataPar", ""), T.iter_var(ax1, T.Range(0, 114), "DataPar", ""), T.iter_var(ax2, T.Range(0, 114), "DataPar", ""), T.iter_var(ax3, T.Range(0, 64), "DataPar", "")], reduce_axis=[], tag=elemwise, attrs={}) along the loop nest specified by compute_at of consumer compute(pool_max, body=[T.reduce(T.comm_reducer(lambda x, y: T.max(x, y), [T.float32(-340282346638528859811704183484516925440.0)]), source=[pad_temp[ax0, ax1 * 2 + rv0, ax2 * 2 + rv1, ax3]], init=[], axis=[T.iter_var(rv0, T.Range(0, 3), "CommReduce", ""), T.iter_var(rv1, T.Range(0, 3), "CommReduce", "")], condition=T.bool(True), value_index=0)], axis=[T.iter_var(ax0, T.Range(0, 1), "DataPar", ""), T.iter_var(ax1, T.Range(0, 56), "DataPar", ""), T.iter_var(ax2, T.Range(0, 56), "DataPar", ""), T.iter_var(ax3, T.Range(0, 64), "DataPar", "")], reduce_axis=[T.iter_var(rv0, T.Range(0, 3), "CommReduce", ""), T.iter_var(rv1, T.Range(0, 3), "CommReduce", "")], tag=pool_max, attrs={"schedule_rule": "meta_schedule.pool_max"})
# Stack trace:
#   0: tvm::te::InferRootBound(tvm::te::Stage const&, tvm::te::GraphContext const&, std::unordered_map<tvm::tir::IterVar, tvm::Range, std::hash<tvm::tir::IterVar>, std::equal_to<tvm::tir::IterVar>, std::allocator<std::pair<tvm::tir::IterVar const, tvm::Range> > >*)
#   1: tvm::te::InferBound(tvm::te::Schedule const&)
#   2: tvm::auto_scheduler::ComputeDAG::InferBound(tvm::auto_scheduler::State const&) const
#   3: tvm::auto_scheduler::ComputeDAG::InferBound(tvm::runtime::Array<tvm::auto_scheduler::State, void> const&) const::{lambda(int)#1}::operator()(int) const
#   4: _ZNSt17_Function_handlerIFSt10unique_ptrINSt13__future_base12_Result_baseENS2_8_DeleterEEvENS1_12_Task_setterIS0_INS1_7_ResultIvEES3_EZNS1_11_Task_stateIZN3tvm7support12parallel_for
#   5: std::__future_base::_State_baseV2::_M_do_set(std::function<std::unique_ptr<std::__future_base::_Result_base, std::__future_base::_Result_base::_Deleter> ()>*, bool*)
#   6: __pthread_once_slow
#         at /build/glibc-LcI20x/glibc-2.31/nptl/pthread_once.c:116
#   7: void std::call_once<void (std::__future_base::_State_baseV2::*)(std::function<std::unique_ptr<std::__future_base::_Result_base, std::__future_base::_Result_base::_Deleter> ()>*, bool*), std::__future_base::_State_baseV2*, std::function<std::unique_ptr<std::__future_base::_Result_base, std::__future_base::_Result_base::_Deleter> ()>*, bool*>(std::once_flag&, void (std::__future_base::_State_baseV2::*&&)(std::function<std::unique_ptr<std::__future_base::_Result_base, std::__future_base::_Result_base::_Deleter> ()>*, bool*), std::__future_base::_State_baseV2*&&, std::function<std::unique_ptr<std::__future_base::_Result_base, std::__future_base::_Result_base::_Deleter> ()>*&&, bool*&&)
#   8: std::thread::_State_impl<std::thread::_Invoker<std::tuple<std::packaged_task<void (std::vector<int, std::allocator<int> > const&, std::function<void (int)> const&)>, std::vector<int, std::allocator<int> >, std::function<void (int)> > > >::_M_run()
#   9: execute_native_thread_routine
#         at /opt/conda/conda-bld/gcc-compiler_1654084175708/work/gcc/libstdc++-v3/src/c++11/thread.cc:82
#   10: start_thread
#         at /build/glibc-LcI20x/glibc-2.31/nptl/pthread_create.c:477
#   11: __clone
#         at ../sysdeps/unix/sysv/linux/x86_64/clone.S:95
#   12: 0xffffffffffffffff
# GA Iter: 4	Max score: 0.9999	Min score: 0.9999	#Pop: 2	#M+: 389	#M-: 6587
# EvolutionarySearch		#s: 2	Time elapsed: 7.75
# ----------------------------------------------------------------------
# ------------------------------  [ Measure ]
# ----------------------------------------------------------------------
# Get 1 programs to measure:
# .*
# Time elapsed for measurement: 2.63 s
# ----------------------------------------------------------------------
# ------------------------------  [ Train cost model ]
# ----------------------------------------------------------------------
# Time elapsed for training: 0.11 s
# ----------------------------------------------------------------------
# ------------------------------  [ Task Scheduler ]
# ----------------------------------------------------------------------
# |  ID  |                       Task Description                        | Latency (ms) | Speed (GFLOPS) | Trials |
# -----------------------------------------------------------------------------------------------------------------
# |    0 |                          vm_mod_fused_nn_conv2d_add_nn_relu_5 |        0.655 |         157.08 |      1 |
# |    1 |                                    vm_mod_fused_nn_conv2d_add |        4.220 |          24.54 |      1 |
# |    2 |                                        vm_mod_fused_nn_conv2d |        2.429 |          42.30 |      1 |
# |    3 |                          vm_mod_fused_nn_conv2d_add_nn_relu_1 |        0.402 |          64.97 |      1 |
# |    4 |                                     vm_mod_fused_nn_dense_add |            - |              - |      1 |
# |    5 |                        vm_mod_fused_nn_conv2d_add_add_nn_relu |        1.002 |         104.96 |      1 |
# |    6 |                                      vm_mod_fused_nn_conv2d_3 |        5.027 |          40.88 |      1 |
# |    7 |                             vm_mod_fused_nn_global_avg_pool2d |        0.007 |          -0.00 |      1 |
# |    8 |                          vm_mod_fused_nn_conv2d_add_nn_relu_8 |        0.814 |          63.15 |      1 |
# |    9 |                                  vm_mod_fused_nn_conv2d_add_3 |        1.263 |          81.44 |      1 |
# |   10 |                          vm_mod_fused_nn_conv2d_add_nn_relu_4 |        1.432 |          36.02 |      1 |
# |   11 |                                      vm_mod_fused_nn_conv2d_1 |            - |              - |      1 |
# |   12 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_1 |        0.452 |         230.07 |      1 |
# |   13 |                                       vm_mod_fused_nn_softmax |        0.206 |           0.02 |      1 |
# |   14 |                                  vm_mod_fused_nn_conv2d_add_2 |        9.900 |          10.40 |      1 |
# |   15 |                         vm_mod_fused_nn_conv2d_add_nn_relu_10 |        2.081 |          49.42 |      1 |
# |   16 |                          vm_mod_fused_nn_conv2d_add_nn_relu_7 |       29.808 |           3.45 |      1 |
# |   17 |                        vm_mod_fused_nn_max_pool2d_add_nn_relu |        0.077 |          28.57 |      1 |
# |   18 |                            vm_mod_fused_nn_conv2d_add_nn_relu |            - |              - |      0 |
# |   19 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu_1 |            - |              - |      0 |
# |   20 |                          vm_mod_fused_nn_conv2d_add_nn_relu_3 |            - |              - |      0 |
# |   21 |               vm_mod_fused_nn_conv2d_add_multiply_add_nn_relu |            - |              - |      0 |
# |   22 |                                  vm_mod_fused_nn_conv2d_add_1 |            - |              - |      0 |
# |   23 |                                      vm_mod_fused_nn_conv2d_2 |            - |              - |      0 |
# |   24 |                          vm_mod_fused_nn_conv2d_add_nn_relu_6 |            - |              - |      0 |
# |   25 |                      vm_mod_fused_nn_conv2d_add_add_nn_relu_2 |            - |              - |      0 |
# |   26 |                          vm_mod_fused_nn_conv2d_add_nn_relu_2 |            - |              - |      0 |
# |   27 | vm_mod_fused_nn_contrib_conv2d_winograd_without_weight_transform_add_nn_relu |            - |              - |      0 |
# |   28 |                          vm_mod_fused_nn_conv2d_add_nn_relu_9 |            - |              - |      0 |
# -----------------------------------------------------------------------------------------------------------------
# Estimated total latency: - ms	Trials: 18	Used time : 276 s	Next ID: 18
# ----------------------------------------------------------------------
# ------------------------------  [ Search ]
# ----------------------------------------------------------------------
# Generate Sketches		#s: 3
# Sample Initial Population	#s: 1796	fail_ct: 0	Time elapsed: 4.27
# GA Iter: 0	Max score: 0.9999	Min score: 0.9991	#Pop: 2	#M+: 0	#M-: 0
